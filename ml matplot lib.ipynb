# %%
#matplot import file
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scater plot in matplot
plt.scatter(x=df["total_bill"],y=df["tip"])

# %%
#change colour into red or green
plt.scatter(x=df["total_bill"],y=df["tip"],c="red")

# %%
#change colour into htmlcolourcode.com to take the colour
#figure is fixing the size of  an cmd
#tittle cmd is use for title
#label cmd is used x lable and ylable
#grid is the grid size to import
plt.figure(figsize=(6,2))
plt.scatter(x=df["total_bill"],y=df["tip"],c="#e1975e",marker="x")
plt.title("billvstip")
plt.xlabel('tip')
plt.ylabel('tbill')
plt.grid()

# %%
#in mat lab is used seaborn also for figgure also fire import sns and plt
plt.figure(figsize=(6,2))
sns.scatterplot(x=df["total_bill"],y=df["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#bar plot to the program to instead y axis change into height
plt.figure(figsize=(6,2))
plt.bar(x=df["smoker"],height=df["tip"],color="#e1975e")
# Out:
# <BarContainer object of 244 artists>

# %%
#bar plot ya xis and width used for an particular coloumn
plt.figure(figsize=(6,2))
plt.barh(y=df["smoker"],width=df["tip"],color="#e1975e")
# Out:
# <BarContainer object of 244 artists>

# %%
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hexbin(x, y, gridsize=20)

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %%
import pandas as pd
ab=pd.read_csv(r"D:\batsman_season_record.csv")

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   batsman  5 non-null      object
#  1   2015     5 non-null      int64
#  2   2016     5 non-null      int64
#  3   2017     5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
#barplot 
plt.bar(ab["batsman"],ab["2015"])
# Out:
# <BarContainer object of 5 artists>

# %%
np.arange(ab.shape[0])
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.figure(figsize=(6,2))
plt.bar(np.arange(ab.shape[0])-0.2,ab["2015"],width=0.2,color="orange")
plt.bar(np.arange(ab.shape[0]),ab["2016"],width=0.2,color="black")
plt.bar(np.arange(ab.shape[0])+0.2,ab["2017"],width=0.2,color="red")
plt.xticks(np.arange(ab.shape[0]),ab["batsman"]) #xsticks is the labling x axis of some names
# Out:
# ([<matplotlib.axis.XTick at 0x1e8ad290190>,
# ...
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])

# %%
plt.figure(figsize=(6,2))
plt.barh(np.arange(ab.shape[0])-0.2,ab["2015"],height=0.2,color="orange")
plt.barh(np.arange(ab.shape[0]),ab["2016"],height=0.2,color="black")
plt.barh(np.arange(ab.shape[0])+0.2,ab["2017"],height=0.2,color="red")
plt.yticks(np.arange(ab.shape[0]),ab["batsman"])
# Out:
# ([<matplotlib.axis.YTick at 0x1e8ad320310>,
# ...
#  [Text(0, 0, 'AB de Villiers'),
#   Text(0, 1, 'DA Warner'),
#   Text(0, 2, 'MS Dhoni'),
#   Text(0, 3, 'RG Sharma'),
#   Text(0, 4, 'V Kohli')])

# %%
x = np.arange(0, 100)
y = x * 2
z = x ** 2
fig, ax = plt.subplots(2, 1)
ax[0].plot(x, y,'r')
ax[0].set_title('Plot of (x, y)')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[1].plot(x, z, 'b')#b is belongs to blue coluour
ax[1].set_title('Plot of (x, z)')
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')


plt.tight_layout()

plt.show()

# %%
Days = [1, 2, 3, 4, 5, 6, 7, 8]
Speed = [60, 62, 61, 58, 56, 57, 46, 63]
plt.plot(Days, Speed)
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.title('Car Speed Measurement')
plt.show()
